# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiyantaabhishek/vehicle_detection_3D/blob/main/vehicleDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Mar  3 02:47:29 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0    29W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/Rock-100/MonoDet.git
# Out:
# Cloning into 'MonoDet'...
# remote: Enumerating objects: 713, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 713 (delta 53), reused 18 (delta 7), pack-reused 613
# Receiving objects: 100% (713/713), 11.27 MiB | 8.57 MiB/s, done.
# Resolving deltas: 100% (210/210), done.

# %%
# %cd  MonoDet
# Out:
# /content/MonoDet

# %%
# !ls
# Out:
# configs     dev			images	      projects		    setup.py
# datasets    docker		INSTALL.md    README_Detectron2.md  tests
# demo	    docs		LICENSE       README.md		    tools
# detectron2  GETTING_STARTED.md	MODEL_ZOO.md  setup.cfg

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating detectron2.egg-info
# writing detectron2.egg-info/PKG-INFO
# writing dependency_links to detectron2.egg-info/dependency_links.txt
# writing requirements to detectron2.egg-info/requires.txt
# writing top-level names to detectron2.egg-info/top_level.txt
# writing manifest file 'detectron2.egg-info/SOURCES.txt'
# /usr/local/lib/python3.8/dist-packages/torch/utils/cpp_extension.py:476: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'detectron2.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'detectron2.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.8
# ...

# %%
# %cd  projects/KITTI
# Out:
# /content/MonoDet/projects/KITTI

# %%
# !python prepare_KITTI.py
# Out:
# val1 train 0
# Traceback (most recent call last):
#   File "prepare_KITTI.py", line 62, in <module>
#     calib = read_calib(calib_path)
#   File "prepare_KITTI.py", line 22, in read_calib
#     f = open(calib_path, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: './training/calib/000000.txt'
